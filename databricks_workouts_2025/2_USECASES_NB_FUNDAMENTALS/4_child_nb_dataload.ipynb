# %%
# %py
import requests
data = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",data.text,True)
print(data.text)
