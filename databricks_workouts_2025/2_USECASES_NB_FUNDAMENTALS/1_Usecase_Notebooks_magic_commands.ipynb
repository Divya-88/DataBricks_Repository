# %% [markdown]
# # **_Assignment 1_** - First usecase of databricks
# ### Task Description
# Document this notebook using markdown features.
# Include a title, a description, your name in color, and our team photo.
# ---
# _⭐ **Divya K**_
# <br>
# <img src="https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg" width="500" height="100"/>
# ---
# **_Use headings, bold, and italics for emphasis as shown above._**

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %run "/Workspace/Users/divyakrish568@gmail.com/DataBricks_Repository/databricks_workouts_2025/2_USECASES_NB_FUNDAMENTALS/4_child_nb_dataload"

# %%
# %fs ls

# %%
# %py
df1 = spark.read.csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv', header=True, inferSchema=True)
display(df1.limit(10))

# %%
# %py
# df1 = df1.withColumnRenamed(
#     "Mobile Operating System", "Mobile_Operating_System"
# ).withColumnRenamed(
#     "Percent of Usage", "Percent_of_Usage"
# )
df1.write.mode("overwrite").saveAsTable("mobile_os_usage")

# %%
# %py
df2 = spark.sql("SELECT * FROM mobile_os_usage")
print(df2)

# %%
# %py
def convert_uppercase():
    text = input("Enter the string")
    return text.upper()

convert_uppercase()

# %%
# %pip install pandas

# %%
# %py

import pandas as pd
df3 = spark.read.csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv')
display(df3.limit(5))

# %%
# %sh
echo "Magic commands tasks completed"
